# %%
import requests

# %%
url =  'https://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle?ServiceKey=%09%20baa6c7c26e5c50eb34cc18013adb92ad90273f569886eb7f8cb0f6e4e180d139&searchYearCd=2021&siDo=11&guGun=650&type=json&numOfRows=10&pageNo=1' 
response = requests.get(url)
print(response)
print(dir(response))
print(type(response))
print(response.json)
# Out:
# <Response [401]>
# ['__annotations__', '__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# <class 'requests.models.Response'>
# <bound method Response.json of <Response [401]>>

# %%
url = 'https://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle?ServiceKey=rcp7JiITf5HDn%2FWoxyEwyGUC36dU%2FLjdFaGd3cIRmo8OSDOzqZ7BB4AVnQUT6FuZRv%2BxIs3Bv6kUjs4UWwxt0Q%3D%3D&searchYearCd=2021&siDo=11&guGun=650&type=json&numOfRows=10&pageNo=1'
response = requests.get(url)
print(response)            #<Response [200]>
print(dir(response))
print(type(response))     # requests.models.Response
print(response.json())
# Out:
# <Response [200]>
# ['__annotations__', '__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# <class 'requests.models.Response'>
# ...

# %%
print(response.text)
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6805806,"afos_id":"2022083","bjd_cd":"1165010100","spot_cd":"11650001","sido_sgg_nm":"서울특별시 서초구1","spot_nm":"서울특별시 서초구 방배동(만남의광장 부근)","occrrnc_cnt":4,"caslt_cnt":4,"dth_dnv_cnt":0,"se_dnv_cnt":1,"sl_dnv_cnt":3,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[126.98413121,37.47696616],[126.98409669,37.476688],[126.98399445,37.47642052],[126.98382842,37.47617402],[126.98360499,37.47595795],[126.98333273,37.47578064],[126.98302212,37.47564887],[126.98268508,37.47556774],[126.98233458,37.47554034],[126.98198407,37.47556774],[126.98164704,37.47564887],[126.98133642,37.47578064],[126.98106417,37.47595795],[126.98084073,37.47617402],[126.98067471,37.47642052],[126.98057247,37.476688],[126.98053795,37.47696616],[126.98057247,37.47724432],[126.98067471,37.47751179],[126.98084073,37.47775829],[126.98106417,37.47797434],[126.98133642,37.47815166],[126.98164704,37.47828341],[126.98198407,37.47836455],[
# ...

# %%
data = response.json()   # 항상 괄호를 붙여서 호출
print(type(data))          # <class 'dict'>
print(data)                  # 실제 데이터 내용 확인
# Out:
# <class 'dict'>
# ...

# %%
# item 접근
w_data = response.json()['items']['item']
print(type(w_data))               # list
print((len(w_data)))              # 갯수


for row in range(len(w_data)):
  print('spot_nm: ', w_data[row]['spot_nm'])
  print('경도: ', w_data[row]['lo_crd'])
  print('위도: ', w_data[row]['la_crd'])
# Out:
# <class 'list'>
# 1
# spot_nm:  서울특별시 서초구 방배동(만남의광장 부근)
# 경도:  126.982334576481
# 위도:  37.476966156164

# %%
result = []
data = response.json()
w_data = data['items']['item']
for row in range(len(w_data)):
  line = {}
  line['spot_nm'] = w_data[row]['spot_nm']
  line['lo_crd'] = w_data[row]['lo_crd']
  line['la_crd'] = w_data[row]['la_crd']
  result.append(line)

# %%
result
# Out:
# [{'spot_nm': '서울특별시 서초구 방배동(만남의광장 부근)',
#   'lo_crd': '126.982334576481',
#   'la_crd': '37.476966156164'}]

# %%
import json

print(dir(json))
# Out:
# ['JSONDecodeError', 'JSONDecoder', 'JSONEncoder', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_default_decoder', '_default_encoder', 'codecs', 'decoder', 'detect_encoding', 'dump', 'dumps', 'encoder', 'load', 'loads', 'scanner']

# %%
#  ensure_ascii=False : 유니코드로 변환되는 작업 방지
# indent ="\t" : 들여쓰기를 탭으로 설정
with open('./cycle.json', 'w',  encoding='utf-8') as f:
   json.dump(result, f, indent='\t', ensure_ascii=False)              # dump(obj, fp)

# %%
with open('./cycle.json', 'r' , encoding='utf-8') as f:
  data = json.load(f)
  print(data)
# Out:
# [{'spot_nm': '서울특별시 서초구 방배동(만남의광장 부근)', 'lo_crd': '126.982334576481', 'la_crd': '37.476966156164'}]

# %% [markdown]
# json.load  : 파일 읽기
# json.dump  : 파일 저장
# json.loads : 문자열(str) -> 객체(list, dict, tuple...)
# json.dumps : 객체(list, dict, tuple...) -> 문자열(str)

# %%
json_str = response.text        # 응답을 문자열로 받기
print(type(json_str))            # <class 'str'>

data = json.loads(json_str)        # 문자열을 딕셔너리로 변환
print(type(data))                    # <class 'dict'>
# Out:
# <class 'str'>
# <class 'dict'>

# %%
print(type(json_str))

data = json.loads(json_str)
print(type(data))
print(data)
# Out:
# <class 'str'>
# <class 'dict'>
# ...

# %%
with open('bicycle_data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print("저장 완료!")
# Out:
# 저장 완료!
